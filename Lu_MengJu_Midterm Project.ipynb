# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

#from datetime import datetime
#from concurrent import futures

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# **import sotck data

# %%
all_stocks = pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv')
df= pd.DataFrame(all_stocks)
df
# Out:
#              Date   Open   High    Low  Close    Volume  Name
# 0      2006-01-03  77.76  79.35  77.24  79.11   3117200   MMM
# 1      2006-01-04  79.49  79.49  78.25  78.71   2558000   MMM
# 2      2006-01-05  78.41  78.65  77.56  77.99   2529500   MMM
# 3      2006-01-06  78.64  78.90  77.64  78.63   2479500   MMM
# 4      2006-01-09  78.50  79.83  78.46  79.02   1845600   MMM
# 5      2006-01-10  79.00  79.01  78.08  78.53   1919900   MMM
# 6      2006-01-11  78.44  78.66  77.84  78.37   1911900   MMM
# 7      2006-01-12  78.20  78.23  77.20  77.70   2121100   MMM
# 8      2006-01-13  76.95  78.20  76.95  77.50   1925300   MMM
# 9      2006-01-17  77.10  77.62  77.00  77.09   2073400   MMM
# 10     2006-01-18  77.00  77.28  76.52  76.99   1838400   MMM
# 11     2006-01-19  77.19  77.37  76.70  76.91   1807100   MMM
# 12     2006-01-20  76.91  76.91  75.18  75.24   3286900   MMM
# 13     2006-01-23  75.50  76.23  74.81  75.70   2953500   MMM
# ...

# %% [markdown]
# **Exploratory Data Analysis,EDA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93612 entries, 0 to 93611
# Data columns (total 7 columns):
# Date      93612 non-null object
# Open      93587 non-null float64
# High      93602 non-null float64
# Low       93592 non-null float64
# Close     93612 non-null float64
# Volume    93612 non-null int64
# Name      93612 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.0+ MB

# %%
# Fix the missing value
if df["Open"].isna().sum()>0:
    df["Open"]=df["Open"].fillna(value=0)
if df["High"].isna().sum()>0:
    df["High"]=df["High"].fillna(value=0)
if df["Low"].isna().sum()>0:
    df["Low"]=df["Low"].fillna(value=0)

# %%
# Trasform Date datatype into datetime 
df["Date"]=pd.to_datetime(df["Date"])

# %%
# First look into overall stockmarket performance from year2006 to year2017
df_all=df
df_all_mean=df_all.groupby("Date")["Close"].mean()
df_all_mean=pd.DataFrame(df_all_mean)
fig, ax = plt.subplots(figsize=(18, 8)) 
df_all_mean['Close'].plot(ax=ax)

style = dict(size=10, color='gray')

# We find out the lowest close price on 2009-03-09, highest on 2017-12-18
# df_all_mean.sort_values(ascending=True).head(1)
# df_all_mean.sort_values(ascending=False).head(1)

ax.text('2009-03-09', 35.01, "2009-03-09", ha='left', **style)
ax.text('2017-12-18', 185.86, "2017-12-18", ha='center', **style)

ax.set(title='Overall Performance of Stock Market from year 2006 to 2017',
       ylabel='average daily close price')
plt.rc('font', size=25)

# %%
# We can see that the close price was at the bottom when there's recession,
# Next, Let's have a look how given 31 stocks performaned

# %%
# Input Seperately data

df_MMM= pd.read_csv('MMM_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_MMM= pd.DataFrame(df_MMM)
df_MMM= df_MMM[["Date","Close","Name"]].set_index('Date')
df_MMMnew=df_MMM.rename(columns={'Close': 'MMM'}).drop(['Name'], axis=1)
#df_MMMnew

df_AXP= pd.read_csv('AXP_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_AXP= pd.DataFrame(df_AXP)
df_AXP= df_AXP[["Date","Close","Name"]].set_index('Date')
df_AXPnew=df_AXP.rename(columns={'Close': 'AXP'}).drop(['Name'], axis=1)
#df_AXPnew

df_AAPL= pd.read_csv('AAPL_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_AAPL= pd.DataFrame(df_AAPL)
df_AAPL= df_AAPL[["Date","Close","Name"]].set_index('Date')
df_AAPLnew=df_AAPL.rename(columns={'Close': 'AAPL'}).drop(['Name'], axis=1)
#df_AAPLnew

df_BA= pd.read_csv('BA_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_BA= pd.DataFrame(df_BA)
df_BA= df_BA[["Date","Close","Name"]].set_index('Date')
df_BAnew=df_BA.rename(columns={'Close': 'BA'}).drop(['Name'], axis=1)
#df_BAnew

df_CAT= pd.read_csv('CAT_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_CAT= pd.DataFrame(df_CAT)
df_CAT= df_CAT[["Date","Close","Name"]].set_index('Date')
df_CATnew=df_CAT.rename(columns={'Close': 'CAT'}).drop(['Name'], axis=1)
#df_CATnew

df_CVX= pd.read_csv('CVX_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_CVX= pd.DataFrame(df_CVX)
df_CVX= df_CVX[["Date","Close","Name"]].set_index('Date')
df_CVXnew=df_CVX.rename(columns={'Close': 'CVX'}).drop(['Name'], axis=1)
#df_CVXnew

df_CSCO= pd.read_csv('CSCO_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_CSCO= pd.DataFrame(df_CSCO)
df_CSCO= df_CSCO[["Date","Close","Name"]].set_index('Date')
df_CSCOnew=df_CSCO.rename(columns={'Close': 'CSCO'}).drop(['Name'], axis=1)
#df_CSCOnew


df_KO= pd.read_csv('KO_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_KO= pd.DataFrame(df_KO)
df_KO= df_KO[["Date","Close","Name"]].set_index('Date')
df_KOnew=df_KO.rename(columns={'Close': 'KO'}).drop(['Name'], axis=1)
#df_KOnew

df_DIS= pd.read_csv('DIS_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_DIS= pd.DataFrame(df_DIS)
df_DIS= df_DIS[["Date","Close","Name"]].set_index('Date')
df_DISnew=df_DIS.rename(columns={'Close': 'DIS'}).drop(['Name'], axis=1)
#df_DISnew

df_XOM= pd.read_csv('XOM_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_XOM= pd.DataFrame(df_XOM)
df_XOM= df_XOM[["Date","Close","Name"]].set_index('Date')
df_XOMnew=df_XOM.rename(columns={'Close': 'XOM'}).drop(['Name'], axis=1)
#df_XOMnew

df_GE= pd.read_csv('GE_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_GE= pd.DataFrame(df_GE)
df_GE= df_GE[["Date","Close","Name"]].set_index('Date')
df_GEnew=df_GE.rename(columns={'Close': 'GE'}).drop(['Name'], axis=1)
#df_GEnew

df_GS= pd.read_csv('GS_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_GS= pd.DataFrame(df_GS)
df_GS= df_GS[["Date","Close","Name"]].set_index('Date')
df_GSnew=df_GE.rename(columns={'Close': 'GS'}).drop(['Name'], axis=1)
#df_GSnew

df_HD= pd.read_csv('HD_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_HD= pd.DataFrame(df_HD)
df_HD= df_HD[["Date","Close","Name"]].set_index('Date')
df_HDnew=df_HD.rename(columns={'Close': 'HD'}).drop(['Name'], axis=1)
#df_HDnew

df_IBM= pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_IBM= pd.DataFrame(df_IBM)
df_IBM= df_IBM[["Date","Close","Name"]].set_index('Date')
df_IBMnew=df_IBM.rename(columns={'Close': 'IBM'}).drop(['Name'], axis=1)
#df_IBMnew

df_INTC= pd.read_csv('INTC_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_INTC= pd.DataFrame(df_INTC)
df_INTC= df_INTC[["Date","Close","Name"]].set_index('Date')
df_INTCnew=df_INTC.rename(columns={'Close': 'INTC'}).drop(['Name'], axis=1)
#df_INTCnew

df_JNJ= pd.read_csv('JNJ_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_JNJ= pd.DataFrame(df_JNJ)
df_JNJ= df_JNJ[["Date","Close","Name"]].set_index('Date')
df_JNJnew=df_JNJ.rename(columns={'Close': 'JNJ'}).drop(['Name'], axis=1)
#df_JNJnew

df_JPM= pd.read_csv('JPM_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_JPM= pd.DataFrame(df_JPM)
df_JPM= df_JPM[["Date","Close","Name"]].set_index('Date')
df_JPMnew=df_JPM.rename(columns={'Close': 'JPM'}).drop(['Name'], axis=1)
#df_JPMnew

df_MCD= pd.read_csv('MCD_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_MCD= pd.DataFrame(df_MCD)
df_MCD= df_MCD[["Date","Close","Name"]].set_index('Date')
df_MCDnew=df_MCD.rename(columns={'Close': 'MCD'}).drop(['Name'], axis=1)
#df_MCDnew

df_MRK= pd.read_csv('MRK_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_MRK= pd.DataFrame(df_MRK)
df_MRK= df_MRK[["Date","Close","Name"]].set_index('Date')
df_MRKnew=df_MRK.rename(columns={'Close': 'MRK'}).drop(['Name'], axis=1)
#df_MRKnew

df_MSFT= pd.read_csv('MSFT_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_MSFT= pd.DataFrame(df_MSFT)
df_MSFT= df_MSFT[["Date","Close","Name"]].set_index('Date')
df_MSFTnew=df_MSFT.rename(columns={'Close': 'MSFT'}).drop(['Name'], axis=1)
#df_MSFTnew

df_NKE= pd.read_csv('NKE_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_NKE= pd.DataFrame(df_NKE)
df_NKE= df_NKE[["Date","Close","Name"]].set_index('Date')
df_NKEnew=df_NKE.rename(columns={'Close': 'NKE'}).drop(['Name'], axis=1)
#df_NKEnew

df_PFE= pd.read_csv('PFE_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_PFE= pd.DataFrame(df_PFE)
df_PFE= df_PFE[["Date","Close","Name"]].set_index('Date')
df_PFEnew=df_PFE.rename(columns={'Close': 'PFE'}).drop(['Name'], axis=1)
#df_PFEnew

df_PG= pd.read_csv('PG_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_PG= pd.DataFrame(df_PG)
df_PG= df_PG[["Date","Close","Name"]].set_index('Date')
df_PGnew=df_PG.rename(columns={'Close': 'PG'}).drop(['Name'], axis=1)
#df_PGnew

df_PG= pd.read_csv('PG_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_PG= pd.DataFrame(df_PG)
df_PG= df_PG[["Date","Close","Name"]].set_index('Date')
df_PGnew=df_PG.rename(columns={'Close': 'PG'}).drop(['Name'], axis=1)
#df_PGnew

df_TRV= pd.read_csv('TRV_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_TRV= pd.DataFrame(df_TRV)
df_TRV= df_TRV[["Date","Close","Name"]].set_index('Date')
df_TRVnew=df_TRV.rename(columns={'Close': 'TRV'}).drop(['Name'], axis=1)
#df_TRVnew

df_UTX= pd.read_csv('UTX_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_UTX= pd.DataFrame(df_UTX)
df_UTX= df_UTX[["Date","Close","Name"]].set_index('Date')
df_UTXnew=df_UTX.rename(columns={'Close': 'UTX'}).drop(['Name'], axis=1)
#df_UTXnew

df_UNH= pd.read_csv('UNH_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_UNH= pd.DataFrame(df_UNH)
df_UNH= df_UNH[["Date","Close","Name"]].set_index('Date')
df_UNHnew=df_UNH.rename(columns={'Close': 'UNH'}).drop(['Name'], axis=1)
#df_UNHnew

df_VZ= pd.read_csv('VZ_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_VZ= pd.DataFrame(df_VZ)
df_VZ= df_VZ[["Date","Close","Name"]].set_index('Date')
df_VZnew=df_VZ.rename(columns={'Close': 'VZ'}).drop(['Name'], axis=1)
#df_VZnew

df_WMT= pd.read_csv('WMT_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_WMT= pd.DataFrame(df_WMT)
df_WMT= df_WMT[["Date","Close","Name"]].set_index('Date')
df_WMTnew=df_WMT.rename(columns={'Close': 'WMT'}).drop(['Name'], axis=1)
#df_WMTnew

df_GOOGL= pd.read_csv('GOOGL_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_GOOGL= pd.DataFrame(df_GOOGL)
df_GOOGL= df_GOOGL[["Date","Close","Name"]].set_index('Date')
df_GOOGLnew=df_GOOGL.rename(columns={'Close': 'GOOGL'}).drop(['Name'], axis=1)
#df_GOOGLnew


df_AMZN= pd.read_csv('AMZN_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_AMZN= pd.DataFrame(df_AMZN)
df_AMZN= df_AMZN[["Date","Close","Name"]].set_index('Date')
df_AMZNnew=df_AMZN.rename(columns={'Close': 'AMZN'}).drop(['Name'], axis=1)
#df_AMZNnew

df_AABA= pd.read_csv('AABA_2006-01-01_to_2018-01-01.csv')
df_AABA= pd.DataFrame(df_AABA)
df_AABA= df_AABA[["Date","Close","Name"]].set_index('Date')
df_AABAnew=df_AABA.rename(columns={'Close': 'AABA'}).drop(['Name'], axis=1)
#df_AABAnew

# %%
New=pd.concat([df_MMMnew,df_AXPnew,df_AAPLnew,df_BAnew,df_CATnew,df_CVXnew,df_CSCOnew,df_KOnew,df_DISnew,df_XOMnew,df_GEnew,df_GSnew,df_HDnew,df_IBMnew,df_INTCnew,
df_JNJnew,df_JPMnew,df_MCDnew,df_MRKnew,df_MSFTnew,df_NKEnew,df_PFEnew,df_PGnew,df_TRVnew,df_UTXnew,df_UNHnew,df_VZnew,df_WMTnew,df_GOOGLnew,df_AMZNnew,df_AABAnew],axis=1,join='outer',sort=False).fillna(0)
#New=New.reset_index()
#New
#New["index"]=pd.to_datetime(New["index"])
#Newf=New.set_index("index")
#Newff=Newf[]
Newf=New

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(20, 15))
Newf['MMM'].plot(ax=ax)
Newf['AXP'].plot(ax=ax)
Newf['AAPL'].plot(ax=ax)
Newf['BA'].plot(ax=ax)
Newf['CAT'].plot(ax=ax)
Newf['CVX'].plot(ax=ax)
Newf['CSCO'].plot(ax=ax)
Newf['KO'].plot(ax=ax)
Newf['DIS'].plot(ax=ax)
Newf['XOM'].plot(ax=ax)
Newf['GE'].plot(ax=ax)
Newf['GS'].plot(ax=ax)
Newf['HD'].plot(ax=ax)
Newf['IBM'].plot(ax=ax)
Newf['INTC'].plot(ax=ax)
Newf['JNJ'].plot(ax=ax)
Newf['JPM'].plot(ax=ax)
Newf['MCD'].plot(ax=ax)
Newf['MRK'].plot(ax=ax)
Newf['MSFT'].plot(ax=ax)
Newf['NKE'].plot(ax=ax)
Newf['PFE'].plot(ax=ax)
Newf['PG'].plot(ax=ax)
Newf['TRV'].plot(ax=ax)
Newf['UTX'].plot(ax=ax)
Newf['UNH'].plot(ax=ax)
Newf['VZ'].plot(ax=ax)
Newf['WMT'].plot(ax=ax)
Newf['GOOGL'].plot(ax=ax)
Newf['AMZN'].plot(ax=ax)
Newf['AABA'].plot(ax=ax)
ax.set(title='Given Stocks Performance in year 2006-2017',
       ylabel='average daily close price')
ax.legend(loc='upper left',fontsize=12)
plt.rc('font', size=18)

# %%
# From above figure, the obivous fluctuaions were Google and Amazon, what about the others?

# %%
# To narrow down for the top 5 maximum fluctuations in the past 10 years: AMZN,GOOGL,BA,UNH,AAPL
df.groupby(["Name"]).std()[['Close']].sort_values(by="Close",ascending=False).head(5)
# Out:
#             Close
# Name
# AMZN   279.980161
# GOOGL  236.343238
# BA      47.480903
# UNH     47.422996
# AAPL    44.536448

# %%
# plot out AMZN,GOOGL,BA,UNH,AAPL to have a cleaer viewing.
fig, ax = plt.subplots(figsize=(25, 12))
Newf['AMZN'].plot(ax=ax)
Newf['GOOGL'].plot(ax=ax)
Newf['BA'].plot(ax=ax)
Newf['UNH'].plot(ax=ax)
Newf['AAPL'].plot(ax=ax)
ax.set(title='Top 5 Stocks Maximum Fluctuation in year 2006-2017',
       ylabel='Average Daily Close Price')
ax.legend(loc='upper left')
plt.rc('font', size=25)

# %%
# How about the fluntuations of these 5 stocks look like during Recession period ?
# Let's break into the time period to around Recession
Newf=New.loc['2007-01-01':'2010-12-31']
fig, ax = plt.subplots(figsize=(25, 12))
Newf['AMZN'].plot(ax=ax)
Newf['GOOGL'].plot(ax=ax)
Newf['BA'].plot(ax=ax)
Newf['UNH'].plot(ax=ax)
Newf['AAPL'].plot(ax=ax)
ax.set(title='Fluctuations during the Recession Period',
       ylabel='Average Daily Close Price')
ax.legend(loc='upper left')
plt.rc('font', size=25)

# %%
# From the figure above, Google is the most affected one during the recession period
# Also, we can find that Amazon and Google has nearly the same trend.
# Interestingly, Apple seemed not affected by the recession siginificantly, while others had obivious downward during 2008.
# Now, let's get a look at their transaction volume variation:

df_GOOGL= pd.read_csv('GOOGL_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_GOOGL= pd.DataFrame(df_GOOGL)
df_GOOGLv= df_GOOGL[["Date","Volume","Name"]].set_index('Date')
df_GOOGLvnew=df_GOOGLv.rename(columns={'Volume': 'GOOGL'}).drop(['Name'], axis=1)
#df_GOOGLnew

df_AAPL= pd.read_csv('AAPL_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_AAPL= pd.DataFrame(df_AAPL)
df_AAPLv= df_AAPL[["Date","Volume","Name"]].set_index('Date')
df_AAPLvnew=df_AAPLv.rename(columns={'Volume': 'AAPL'}).drop(['Name'], axis=1)
#df_AAPLnew

df_BA= pd.read_csv('BA_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_BA= pd.DataFrame(df_BA)
df_BAv= df_BA[["Date","Volume","Name"]].set_index('Date')
df_BAvnew=df_BAv.rename(columns={'Volume': 'BA'}).drop(['Name'], axis=1)
#df_BAnew

df_UNH= pd.read_csv('UNH_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_UNH= pd.DataFrame(df_UNH)
df_UNHv= df_UNH[["Date","Volume","Name"]].set_index('Date')
df_UNHvnew=df_UNHv.rename(columns={'Volume': 'UNH'}).drop(['Name'], axis=1)
#df_UNHnew

df_AMZN= pd.read_csv('AMZN_2006-01-01_to_2018-01-01.csv',parse_dates=["Date"])
df_AMZN= pd.DataFrame(df_AMZN)
df_AMZNv= df_AMZN[["Date","Volume","Name"]].set_index('Date')
df_AMZNvnew=df_AMZNv.rename(columns={'Volume': 'AMZN'}).drop(['Name'], axis=1)
#df_AMZNnew


Newv=pd.concat([df_UNHvnew,df_GOOGLvnew,df_AMZNvnew,df_BAvnew,df_AAPLvnew],axis=1,join='outer',sort=False).fillna(0)
NewV=Newv.loc['2007-01-01':'2010-12-31']
NewV
fig, ax = plt.subplots(figsize=(25, 12))
NewV['AMZN'].plot(ax=ax)
NewV['GOOGL'].plot(ax=ax)
NewV['BA'].plot(ax=ax)
NewV['UNH'].plot(ax=ax)
NewV['AAPL'].plot(ax=ax)
ax.set(title='Volume Variations during the Recession Period',
       ylabel='Average Daily Transaction Volume')
ax.legend(loc='upper left')
plt.rc('font', size=20)
# The result looks so interesting that Apple had the largest volume during reseccion period, 
# once again, proved that APPLE had the least shock by the recession.

# %%
# Summarize for these 5 highlighted stocks!
df_all=df
df_gv=df_all[(df_all['Date']<='2010-12-31') & (df_all['Date']>'2007-01-01')]
df_gv=df_gv.groupby("Name").mean().reset_index("Name")
df_gv[(df_gv["Name"]=="GOOGL") | (df_gv["Name"]=="AAPL")| (df_gv["Name"]=="AMZN")| (df_gv["Name"]=="BA")| (df_gv["Name"]=="UNH")].sort_values(by="Close",ascending=False).head(5)
# Out:
#      Name        Open        High         Low       Close        Volume
# 10  GOOGL  247.725154  250.611092  244.533962  247.538252  4.626079e+06
# 2    AMZN   90.703098   92.312642   89.167746   90.844926  8.888744e+06
# 4      BA   68.166012   68.888929   67.125089   68.022629  6.440998e+06
# 26    UNH   35.921746   36.462798   35.361220   35.912589  1.039939e+07
# 1    AAPL   24.181013   24.495154   23.808471   24.167746  2.054075e+08

# %%
# Next, let's check, besides APPLE, what companies still had active transaction during recession period.

# %%
# graph all trasaction volume: 
plt.figure(figsize=(25, 12))
x=np.arange(len(df_gv.index))+1 
y=np.array(list(df_gv['Volume']))
xticks1=list(df_gv['Name']) 
plt.bar(x,y,width = 0.35,align='center',color = 'c',alpha=0.8)
plt.xticks(x,xticks1,size='small',rotation=30)

plt.xlabel('Ticker')
plt.ylabel('Volume')
plt.title('Average transactons during the Recession Period')

plt.ylim(0,)
plt.show()

# %%
# Break top five activest transaction volume in detail:
df_g=df_all[(df_all['Date']<='2010-12-31') & (df_all['Date']>'2007-01-01')]
df_gv=df_g.groupby("Name").mean().reset_index("Name")
df_gv.sort_values(by="Volume",ascending=False).head(5)
# Out:
#     Name       Open       High        Low      Close        Volume
# 1   AAPL  24.181013  24.495154  23.808471  24.167746  2.054075e+08
# 9     GE  23.944256  24.226448  23.597470  23.908363  7.655171e+07
# 21  MSFT  26.779007  27.099206  26.455501  26.776236  6.809130e+07
# 14  INTC  20.309037  20.581658  20.030675  20.306187  6.705152e+07
# 6   CSCO  23.559215  23.876981  23.233396  23.555452  5.649477e+07

# %%
# Now let's look at the overall data (2006-2017) between GOOGLE and Amazon (Q3 starts)
df2=df.groupby("Name").mean().reset_index("Name")
df2[(df2["Name"]=="GOOGL") | (df2["Name"]=="AMZN")]
# Out:
#      Name        Open        High         Low       Close        Volume
# 2    AMZN  299.335310  302.371163  296.037695  299.376231  5.931712e+06
# 10  GOOGL  428.200802  431.835618  424.130275  428.044001  3.551504e+06

# %%
# Last 1 month in 2017, simple moving average:
df2_1=df[(df['Date']<='2017-12-31') & (df['Date']>'2017-12-01')]
df2_1=df2_1[(df2_1["Name"]=="GOOGL") | (df2_1["Name"]=="AMZN")]
df2_1.groupby(["Name"]).mean()[["Open",'Close']]
# Out:
#               Open        Close
# Name
# AMZN   1170.818947  1169.183158
# GOOGL  1055.495263  1055.435789

# %%
# Last 1 month in 2017 transaction days:
a=df2_1["Date"].nunique()
print('There were',a,'trasaction days.')
# Out:
# There were 19 trasaction days.

# %%
# Last 1 month in 2017 , who had the highest Open value: AMAZON, 2017/12/20, $1,190.5
df2_1.sort_values(by="Open",ascending=False).head(1)[["Name","Date","Open"]]
# Out:
#        Name       Date    Open
# 90586  AMZN 2017-12-20  1190.5

# %%
# Last 1 month in 2017, who had the Lowest Close value: AMAZON, 2017/12/18, $1,187.37
df2_1.sort_values(by="Close",ascending=False).head(1)[["Name","Date","Open"]]
# Out:
#        Name       Date     Open
# 90584  AMZN 2017-12-18  1187.37

# %%
# Last 1 month in 2017, who had the most variations of close value:GOOGLE
df2_1.groupby(["Name"]).std()[['Close']].sort_values(by="Close",ascending=False).head(1)
# Out:
#            Close
# Name
# GOOGL  19.087693

# %%
# Finally, let's have a look for the top 5 transaction volume in recession period : AAPL,GE,MSFT,INTC,CSCO  (Q4 starts)
# simple moving average:
df5=df[(df['Date']<='2010-12-31') & (df['Date']>'2007-01-01')]
df5=df5[(df5["Name"]=="AAPL") | (df5["Name"]=="GE")| (df5["Name"]=="MSFT")| (df5["Name"]=="INTC")| (df5["Name"]=="CSCO")]
df5.groupby(["Name"]).mean()[["Open",'Close']]
# Out:
#            Open      Close
# Name
# AAPL  24.181013  24.167746
# CSCO  23.559215  23.555452
# GE    23.944256  23.908363
# INTC  20.309037  20.306187
# MSFT  26.779007  26.776236

# %%
# who had the highest Open value: AAPL, 2010/12/29, $46.6
df5.sort_values(by="Open",ascending=False).head(1)[["Name","Date","Open"]]
# Out:
#       Name       Date  Open
# 7295  AAPL 2010-12-29  46.6

# %%
# who had the lowest Close value: GE, 2009/3/5, $6.75
df5.sort_values(by="Close",ascending=True).head(1)[["Name","Date","Open"]]
# Out:
#       Name       Date  Open
# 30995   GE 2009-03-05  6.75

# %%
# Whoes price were below $10 and when were them ?
df5[df5["Close"]<10][["Name","Date","Close"]]
# Out:
#       Name       Date  Close
# 30986   GE 2009-02-20   9.38
# 30987   GE 2009-02-23   8.85
# 30988   GE 2009-02-24   9.08
# 30989   GE 2009-02-25   9.01
# 30990   GE 2009-02-26   9.10
# 30991   GE 2009-02-27   8.51
# 30992   GE 2009-03-02   7.60
# 30993   GE 2009-03-03   7.01
# 30994   GE 2009-03-04   6.69
# 30995   GE 2009-03-05   6.66
# 30996   GE 2009-03-06   7.06
# 30997   GE 2009-03-09   7.41
# 30998   GE 2009-03-10   8.87
# 30999   GE 2009-03-11   8.49
# 31000   GE 2009-03-12   9.57
# 31001   GE 2009-03-13   9.62
# 31002   GE 2009-03-16   9.66
# 31006   GE 2009-03-20   9.54
# 31012   GE 2009-03-30   9.93

# %%
# Who had the most variations of close value:GE
df5.groupby(["Name"]).std()[['Close']].sort_values(by="Close",ascending=False).head(1)
# Out:
#          Close
# Name
# GE    10.36929
